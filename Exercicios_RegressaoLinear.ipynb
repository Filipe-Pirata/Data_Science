# %% [markdown]
# <a href="https://colab.research.google.com/github/Filipe-Pirata/Data_Science/blob/main/Exercicios_RegressaoLinear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Atividade 1: Implementando a Função de Custo** (Nível: Fácil)
# Objetivo: Implementar a função compute_cost() e testá-la com um conjunto de dados simples.
#
# 🔹 Passos:
#
#
# 1.   Criar um array x representando uma variável independente (exemplo: população de cidades).
# 2.   Criar um array y representando a variável dependente (exemplo: lucro das cidades).
# 3.   Definir valores iniciais de w e b.
# 4.   Implementar e chamar a função compute_cost(x, y, w, b).
# 5.   Exibir o custo retornado.

# %%
import numpy as np
from matplotlib import pyplot as plt


x = np.array([1, 2, 3, 4, 5])
y = np.array([1, 2, 3, 4, 5])

w = 0.5
b = 0.5

plt.scatter(x, y, marker='x', color='red', label="Dados reais")
plt.plot(x, w * x + b, label="Predição Inicial", color="blue")
plt.xlabel("População")
plt.ylabel("Lucro")
plt.legend()
plt.show()

def compute_cost(x, y, w, b):
    m = x.shape[0] #numero de exemplos
    cost_sum = 0

    for i in range(m):
        f_wb = w * x[i] + b
        cost = (f_wb - y[i]) ** 2
        cost_sum += cost
    total_cost = (1 / (2 * m)) * cost_sum
    return total_cost

custo = compute_cost(x, y, w, b)


def gradient_descent(x, y, w, b, alpha, iterations):
    m = x.shape[0]

   for i in range(iterations):


print(f"Custo do modelo: {custo:.2f}")
# Out:
# Custo do modelo: 0.75

# %% [markdown]
# 📌 **Atividade 2: Ajustando a Função de Custo com Gradient Descent** (Nível: Médio)
# Objetivo: Criar um loop que ajusta w e b minimizando o custo usando o Gradiente Descendente.
#
# 🔹 Passos:
#
#
#
# 1.   Criar uma função gradient_descent(x, y, w, b, alpha, iterations).
# 2.   Dentro da função, atualizar w e b usando as fórmulas do Gradiente Descendente.
# 3.   Testar o código com diferentes valores de alpha e iterations.
# 4.   Imprimir os valores finais de w e b.
# 5.   Comparar o custo inicial e final.

# %%
import numpy as np
from matplotlib import pyplot as plt


x = np.array([1, 2, 3, 4, 5])
y = np.array([1, 2, 3, 4, 5])

w = 0.5
b = 0.5

plt.scatter(x, y, marker='x', color='red', label="Dados reais")
plt.plot(x, w * x + b, label="Predição Inicial", color="blue")
plt.xlabel("População")
plt.ylabel("Lucro")
plt.legend()
plt.show()


#Parametros do Gradient
theta_0 = 0 # Intercepto
theta_1  = 0 # Coeficiente angular
alpha = 0.01 # valor da taxa de aprendizado
iterations = 1000
m = len(x)

# Gradient Descendente
for _ in range(iterations):
  h = theta_0 + theta_1 * x  # Hipotese
  erro = h - y #Previsao - Real

  # Calculo do Gradient

  grad_theta_0 = (1/m) * np.sum(erro)
  grad_theta_1  = (1/m) * np.sum(erro * x)

  theta_0 -= alpha * grad_theta_0
  theta_1 -= alpha * grad_theta_1

# Parâmetros  aprendidos
print(f"Parâmetros finais: theta_0 = {theta_0:.4f}, theta_1 = {theta_1:.4f}")

#Funcao de Custo

def compute_cost(x, y, w, b):
    m = x.shape[0] # numero de exemplos
    cost_sum = 0

    for i in range(m):
        f_wb = w * x[i] + b
        cost = (f_wb - y[i]) ** 2
        cost_sum += cost
    total_cost = (1 / (2 * m)) * cost_sum
    return total_cost

custo = compute_cost(x, y, theta_1, theta_0)
print(f"Custo do modelo: {custo:.2f}")

print("###### NOVOS DADOS ######")


x_novos = np.array([6, 7, 8, 9, 10])
y_previstos = theta_0 + theta_1 * x_novos

plt.scatter(x, y, marker='x', color='red', label="Dados reais")
plt.plot(x, theta_1 * x + theta_0, label="Predição Final", color="green")

for i in range(len(x_novos)):
  print(f"Para x = {x_novos[i]}, previsão de y = {y_previstos[i]:.2f}")
# Out:
# Parâmetros finais: theta_0 = 0.0474, theta_1 = 0.9869
# Custo do modelo: 0.00
# ###### NOVOS DADOS ######
# Para x = 6, previsão de y = 5.97
# Para x = 7, previsão de y = 6.96
# Para x = 8, previsão de y = 7.94
# Para x = 9, previsão de y = 8.93
# Para x = 10, previsão de y = 9.92
